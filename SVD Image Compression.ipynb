# %%
import numpy as np
from random import randrange
import os
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
img = Image.open(r'D:\Downloads\test1\test1\11045.jpg').convert('L')
x = np.array(img.resize((128,128)))
imshow(img,cmap='gray')

# %%
U,S,V = np.linalg.svd(x, full_matrices=False)
S = np.diag(S)

# %%
r = 100
reconstruction = U[:,:r] @ S[0:r,:r] @ V[:r,:]

# %%
imshow(reconstruction,cmap='gray')

# %%
plt.plot(np.cumsum(S)/np.sum(S))
plt.title('Cumulative Sum of Sigma Matrix')
# Out:
# Text(0.5, 1.0, 'Cumulative Sum of Sigma Matrix')
